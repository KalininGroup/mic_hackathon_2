# %% [markdown]
# # DeepTrack + Copilot Analysis Demo
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Abhishek-Gupta-GitHub/confocal_microscopy-copilot/blob/main/notebooks/deeptrack_analysis_demo.ipynb)
#
# This notebook shows how to:
# - Generate synthetic 2D+t data with DeepTrack (or a fallback).
# - Run DeepTrack-based detection + Trackpy tracking via the copilot.
# - Analyze trajectories with `PhysicsAnalystAdvanced`.
# - Compare to your existing digital twin synthetic data.

# %%
import os, sys

# If running from VS Code inside the repo:
repo_root = os.path.abspath(os.path.join(os.getcwd(), "..")) if os.path.basename(os.getcwd()) == "notebooks" else os.getcwd()
print("Repo root:", repo_root)

if repo_root not in sys.path:
    sys.path.insert(0, repo_root)
# Out:
# Repo root: c:\Users\akumarg\Desktop\microscopy hackathon\confocal_microscopy-copilot

# %%
import numpy as np
import matplotlib.pyplot as plt

from copilot.detection_deeptrack import DeepTrackDetector, DeepTrackConfig
from src.analysis.physics_analyst_basic import Trajectory
from copilot.digital_twin import DigitalTwin
from copilot.orchestrator import Orchestrator
from src.analysis.physics_analyst_advanced import PhysicsAnalystAdvanced  # or your current module
from copilot.config import DEFAULT_META
from copilot.detection_tracking import DetectionTrackingWorker
from copilot.detection_tracking import DetectionTrackingWorker
# Out:
# C:\Users\akumarg\AppData\Roaming\Python\Python311\site-packages\deeptrack\__init__.py:14: UserWarning: TensorFlow is detected in your environment. DeepTrack2 version 2.0++ no longer supports TensorFlow. If you need TensorFlow support, please install the legacy version 1.7 of DeepTrack2:
#
#     pip install deeptrack==1.7
#
# For more details, refer to the DeepTrack documentation.
#   warnings.warn(
# WARNING:pint.util:Redefining '[magnetic_flux]' (<class 'pint.delegates.txt_defparser.plain.DerivedDimensionDefinition'>)

# %%
import os, sys

repo_root = os.path.abspath(os.path.join(os.getcwd(), ".."))  # if in notebooks/
if repo_root not in sys.path:
    sys.path.insert(0, repo_root)

from copilot.detection_deeptrack import DeepTrackDetector, DeepTrackConfig
from copilot.detection_tracking import DetectionTrackingWorker
from copilot.digital_twin import DigitalTwin
from copilot.orchestrator import Orchestrator, Plan
from src.analysis.physics_analyst_advanced import PhysicsAnalystAdvanced
from copilot.config import DEFAULT_META

# %% [markdown]
# Generate DeepTrack synthetic 2D+t (code)

# %%
dt_cfg = DeepTrackConfig(image_shape=(64, 64), particle_radius_px=2.5)
dt_detector = DeepTrackDetector(dt_cfg)

stack_2d_t = dt_detector.generate_synthetic_2d_t(n_frames=100)
print("Synthetic DeepTrack stack shape (T, H, W):", stack_2d_t.shape)


# Quick visualization of a few frames
fig, axes = plt.subplots(1, 3, figsize=(9, 3))
for i, ax in enumerate(axes):
    ax.imshow(stack_2d_t[i * 10], cmap="magma")
    ax.set_title(f"Frame {i * 10}")
    ax.axis("off")
plt.tight_layout()
plt.show()
# Out:
# Synthetic DeepTrack stack shape (T, H, W): (100, 64, 64)

# %% [markdown]
# Wrap 2D+t into fake 3D stack for copilot (code)

# %%
# Your copilot expects 3D stacks (T, Z, H, W). Wrap 2D as Z=1 slice.
T, H, W = stack_2d_t.shape
stack_3d = stack_2d_t[:, None, :, :]  # shape (T, 1, H, W)

print("Wrapped stack_3d shape:", stack_3d.shape)
# Out:
# Wrapped stack_3d shape: (100, 1, 64, 64)

# %% [markdown]
# Plan via Orchestrator (code)

# %%
import inspect
from copilot.orchestrator import Orchestrator

print(inspect.signature(Orchestrator.make_plan))
# Out:
# (self, user_query: str, metadata: dict, quick_stats: dict) -> copilot.orchestrator.Plan

# %%
from copilot.orchestrator import Orchestrator, Plan
from copilot.config import DEFAULT_META

orchestrator = Orchestrator()
user_question = "Analyze diffusion and heterogeneity in this DeepTrack synthetic dataset."

quick_stats = {}  # or prefill if you like, e.g. {"density_est": 200, "D_est": 0.2}

plan = orchestrator.make_plan(
    user_query=user_question,
    metadata=DEFAULT_META,
    quick_stats=quick_stats,
)

plan
# Out:
# Plan(pipeline_type='diffusion', twin_needed=True, twin_settings={'n_particles': 200, 'D': 0.2, 'n_frames': 100, 'dt': 0.1}, detection_params_initial={'min_sigma': 1, 'max_sigma': 4, 'threshold': 2.5, 'minmass': 200.0}, tracking_params_initial={'search_range': 1.0, 'memory': 2})

# %%
meta_dt = DEFAULT_META.copy()
meta_dt["dataset_id"] = "deeptrack_synthetic"

plan = orchestrator.make_plan(
    user_query=user_question,
    metadata=meta_dt,
    quick_stats=quick_stats,
)

# %%
# After plan = orchestrator.make_plan(...)
plan.tracking_params_initial["search_range"] = 2.0  # or even 1.0 for small motion
plan.tracking_params_initial["memory"] = 1

# %% [markdown]
# Detection + tracking using DeepTrack backend (code)

# %%
det_worker = DetectionTrackingWorker()

dt_result = det_worker.run_with_deeptrack(stack_3d, plan)
trajectories = dt_result["trajectories"]
qm = dt_result["quality_metrics"]

print("Detection backend:", qm["backend"])
print("Number of tracks:", qm["n_tracks"])
print("Detections per frame (first 5):", dict(list(qm["detections_per_frame"].items())[:5]))
# Out:
# ---------------------------------------------------------------------------
# SubnetOversizeException                   Traceback (most recent call last)
# Cell In[11], line 3
#       1 det_worker = DetectionTrackingWorker()
# ----> 3 dt_result = det_worker.run_with_deeptrack(stack_3d, plan)
#       4 trajectories = dt_result["trajectories"]
#       5 qm = dt_result["quality_metrics"]
#
# File c:\Users\akumarg\Desktop\microscopy hackathon\confocal_microscopy-copilot\copilot\detection_tracking.py:138, in DetectionTrackingWorker.run_with_deeptrack(self, stack_3d, plan)
#     129 # Convert to DataFrame expected by trackpy: columns ['frame','x','y']
#     130 df = pd.DataFrame(
#     131     {
#     132         "frame": positions[:, 0].astype(int),
#    (...)
#     135     }
#     136 )
# --> 138 linked = tp.link_df(
#     139     df,
#     140     search_range=plan.tracking_params_initial.get("search_range", 5),
#     141     memory=plan.tracking_params_initial.get("memory", 2),
#     142 )
#     144 trajectories = self._df_to_trajectories(linked, stack_3d.shape)
#     146 detections_per_frame = df["frame"].value_counts().sort_index().to_dict()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\trackpy\linking\linking.py:192, in link(f, search_range, pos_columns, t_column, **kwargs)
#     190 coords_iter = coords_from_df(f, pos_columns, t_column)
#     191 ids = []
# --> 192 for i, _ids in link_iter(coords_iter, search_range, **kwargs):
#     193     ids.extend(_ids)
#     195 f['particle'] = ids
#
# File ~\AppData\Roaming\Python\Python311\site-packages\trackpy\linking\linking.py:102, in link_iter(coords_iter, search_range, **kwargs)
#      99 yield t, linker.particle_ids
#     101 for t, coords in coords_iter:
# --> 102     linker.next_level(coords, t)
#     103     logger.info("Frame {}: {} trajectories present.".format(t, len(linker.particle_ids)))
#     104     yield t, linker.particle_ids
#
# File ~\AppData\Roaming\Python\Python311\site-packages\trackpy\linking\linking.py:511, in Linker.next_level(self, coords, t, extra_data)
#     507 prev_hash = self.update_hash(coords, t, extra_data)
#     509 self.subnets = Subnets(prev_hash, self.hash, self.search_range,
#     510                        self.MAX_NEIGHBORS)
# --> 511 spl, dpl = self.assign_links()
#     512 self.apply_links(spl, dpl)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\trackpy\linking\linking.py:520, in Linker.assign_links(self)
#     517 for sp in source_set:
#     518     sp.forward_cands.sort(key=lambda x: x[1])
# --> 520 sn_spl, sn_dpl = self.subnet_linker(source_set, dest_set,
#     521                                     self.search_range)
#     522 spl.extend(sn_spl)
#     523 dpl.extend(sn_dpl)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\trackpy\linking\subnetlinker.py:461, in subnet_linker_numba(source_set, dest_set, search_range, hybrid, **kwargs)
#     459     sn_spl, sn_dpl = recursive_linker_obj(source_set, lds, search_range, **kwargs)
#     460 else:
# --> 461     sn_spl, sn_dpl = numba_link(source_set, lds, search_range, **kwargs)
#     463 for dp in dest_set - set(sn_dpl):
#     464     # Unclaimed destination particle in subnet
#     465     sn_spl.append(None)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\trackpy\linking\subnetlinker.py:208, in numba_link(s_sn, dest_size, search_range, max_size, diag)
#     206 ncands[j] = len(sp.forward_cands)
#     207 if ncands[j] > max_candidates:
# --> 208     raise SubnetOversizeException('search_range (aka maxdisp) too large for reasonable performance '
#     209                                   'on these data (particle has %i forward candidates)' % ncands[j])
#     210 candsarray[j,:ncands[j]] = [dcands_map[cand] for cand, dist in sp.forward_cands]
#     211 distsarray[j,:ncands[j]] = [dist for cand, dist in sp.forward_cands]
#
# SubnetOversizeException: search_range (aka maxdisp) too large for reasonable performance on these data (particle has 11 forward candidates)

# %% [markdown]
# Visualize a few tracks (code)

# %%
if len(trajectories) == 0:
    print("No trajectories to show.")
else:
    # Simple x–y scatter colored by time
    xs = np.array([traj.x for traj in trajectories])
    ys = np.array([traj.y for traj in trajectories])
    ts = np.array([traj.t for traj in trajectories])

    plt.figure(figsize=(4, 4))
    sc = plt.scatter(xs, ys, c=ts, s=5, cmap="viridis")
    plt.colorbar(sc, label="time (frame)")
    plt.gca().invert_yaxis()
    plt.xlabel("x [px]")
    plt.ylabel("y [px]")
    plt.title("DeepTrack-based trajectories (2D projection)")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# PhysicsAnalystAdvanced on DeepTrack trajectories (code)

# %%
# Assuming your PhysicsAnalystAdvanced takes (dt, pixel_size, dim, wall_z_threshold, etc.)
dt = 1.0  # arbitrary frame interval for synthetic DeepTrack example
pixel_size_um = DEFAULT_META["voxel_size_um"][0]

analyzer = PhysicsAnalystAdvanced(
    dt=dt,
    px_to_um=pixel_size_um,
    dim=2,
    wall_z_threshold=None,
)

summary = analyzer.summarize_physics(trajectories, domain="colloidal")
print("Keys in summary:", list(summary.keys()))
print("Flags:", summary.get("flags", {}))

# %% [markdown]
# MSD and heterogeneity plots (code)

# %% [markdown]
# # Adapt to your existing summary structure
# msd = np.array(summary["msd"]["values"])
# lags = np.array(summary["msd"]["lags"])
# alpha = summary["msd"]["fit_exponent"]
# D_est = summary["msd"]["D_estimate"]
#
# plt.figure(figsize=(4, 4))
# plt.loglog(lags, msd, "o-", label="MSD")
# plt.loglog(lags, D_est * lags**alpha, "--", label=f"fit α={alpha:.2f}")
# plt.xlabel("lag time")
# plt.ylabel("MSD [µm²]")
# plt.legend()
# plt.title("DeepTrack synthetic: MSD")
# plt.tight_layout()
# plt.show()
#
# # Example: non-Gaussian parameter if present
# if "non_gaussian" in summary:
#     lags_ng = np.array(summary["non_gaussian"]["lags"])
#     alpha2 = np.array(summary["non_gaussian"]["alpha2"])
#     plt.figure(figsize=(4, 3))
#     plt.plot(lags_ng, alpha2, "o-")
#     plt.xlabel("lag time")
#     plt.ylabel(r"$\alpha_2$")
#     plt.title("Non-Gaussian parameter")
#     plt.tight_layout()
#     plt.show()

# %% [markdown]
# Compare to DigitalTwin synthetic 3D+t (code)

# %% [markdown]
# # Use your existing twin to simulate a comparable 3D+t dataset
# twin = DigitalTwin()
# microscope_config = {
#     "NA": 1.3,
#     "wavelength_nm": 550.0,
#     "immersion_ri": 1.518,
#     "pixel_size_um": pixel_size_um,
#     "z_step_um": DEFAULT_META["voxel_size_um"][2],
#     "mode": "gaussian_confocal",
# }
# sample_config = {
#     "object_type": "beads",
#     "size_distribution": [3.0, 0.5],
#     "brightness": 1.0,
#     "volume_fraction": 0.1,
#     "medium_type": "viscous",
#     "wall_position_flag": False,
# }
#
# stack_twin = twin.simulate(microscope_config, sample_config, n_frames=100)
# print("Twin stack shape:", stack_twin.shape)
#
# # Reuse your “standard” DetectionTrackingWorker.run (not DeepTrack) + analyzer here.

# %% [markdown]
# ## Notes and next steps
#
# - This notebook demonstrates a DeepTrack-based path and a DigitalTwin-based path.
# - You can extend `DeepTrackDetector` with:
#   - 3D data generators (DeepTrack 3D PointParticle).
#   - Trained CNN localizers from DeepTrack tutorials (DTEx212, DTEx213).
# - The same `PhysicsAnalystAdvanced` works for 2D, 2D+t, 3D, 3D+t as long as trajectories follow the unified schema.
