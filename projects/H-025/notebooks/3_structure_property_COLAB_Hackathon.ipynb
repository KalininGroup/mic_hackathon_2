# %% [markdown]
# ## Structure-Property relationship using EELS data
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/pycroscopy/DTMicroscope/blob/main/notebooks/STEM/3_structure_property_COLAB-Hackathon.ipynb)
#
#   Establishing a clear understanding of the structure-property relationship is a cornerstone in materials science, as it enables us to predict and optimize material performance for a range of applications. This relationship provides insights into why materials exhibit certain behaviors under specific conditions, thus guiding the development of materials with tailored properties.
#
#   However, bridging the gap between structure and properties is complex. Predicting what a material’s structure looks like from its properties—or vice versa—presents unique challenges, often requiring sophisticated data analysis and modeling. In this notebook, we’ll use Electron Energy Loss Spectroscopy (EELS) data to develop a workflow that can help us make these predictions.
#
#   Our goal is to uncover insights into material behavior by building connections between what we see (structure) and how it performs (properties).

# %% [markdown]
# ## Server setup

# %%
# !pip install -q pyro5
# !pip install -q scifireaders
# !pip install -q sidpy
# !pip install -q pynsid
# !pip install -q git+https://github.com/pycroscopy/DTMicroscope.git
# !pip install atomai
# !pip install pytemlib
# Out:
# Collecting atomai
#   Using cached atomai-0.8.1-py3-none-any.whl.metadata (15 kB)
# Collecting torch>=1.0.0 (from atomai)
#   Downloading torch-2.9.1-cp310-cp310-win_amd64.whl.metadata (30 kB)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from atomai) (2.2.6)
# Requirement already satisfied: matplotlib>=3.4 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from atomai) (3.10.8)
# Requirement already satisfied: scipy>=1.3.0 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from atomai) (1.15.3)
# Requirement already satisfied: scikit-learn>=0.22.1 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from atomai) (1.7.2)
# Collecting scikit-image>=0.16.2 (from atomai)
#   Using cached scikit_image-0.25.2-cp310-cp310-win_amd64.whl.metadata (14 kB)
# Collecting opencv-python>=4.1.0 (from atomai)
#   Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (19 kB)
# Collecting networkx>=2.5 (from atomai)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting mendeleev<=0.6.1 (from atomai)
#   Using cached mendeleev-0.6.1-py2.py3-none-any.whl
# Collecting torchvision>=0.13.0 (from atomai)
#   Using cached torchvision-0.24.1-cp310-cp310-win_amd64.whl.metadata (5.9 kB)
# Collecting progressbar2>=3.38.0 (from atomai)
#   Using cached progressbar2-4.5.0-py3-none-any.whl.metadata (16 kB)
# Collecting gpytorch>=1.9.1 (from atomai)
#   Using cached gpytorch-1.14.3-py3-none-any.whl.metadata (8.3 kB)
# Collecting pandas>=1.1.5 (from atomai)
#   Using cached pandas-2.3.3-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Collecting sqlalchemy>=1.3.0 (from mendeleev<=0.6.1->atomai)
#   Using cached sqlalchemy-2.0.45-cp310-cp310-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: colorama in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from mendeleev<=0.6.1->atomai) (0.4.6)
# Collecting pyfiglet (from mendeleev<=0.6.1->atomai)
#   Using cached pyfiglet-1.0.4-py3-none-any.whl.metadata (7.4 kB)
# Collecting jaxtyping (from gpytorch>=1.9.1->atomai)
#   Using cached jaxtyping-0.3.4-py3-none-any.whl.metadata (7.8 kB)
# Collecting mpmath<=1.3,>=0.19 (from gpytorch>=1.9.1->atomai)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting linear_operator>=0.6 (from gpytorch>=1.9.1->atomai)
#   Using cached linear_operator-0.6-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from matplotlib>=3.4->atomai) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from matplotlib>=3.4->atomai) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from matplotlib>=3.4->atomai) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from matplotlib>=3.4->atomai) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from matplotlib>=3.4->atomai) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from matplotlib>=3.4->atomai) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from matplotlib>=3.4->atomai) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from matplotlib>=3.4->atomai) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas>=1.1.5->atomai)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.1.5->atomai)
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-utils>=3.8.1 (from progressbar2>=3.38.0->atomai)
#   Using cached python_utils-3.9.1-py2.py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: six>=1.5 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.4->atomai) (1.17.0)
# Requirement already satisfied: typing_extensions>3.10.0.2 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from python-utils>=3.8.1->progressbar2>=3.38.0->atomai) (4.15.0)
# Collecting imageio!=2.35.0,>=2.33 (from scikit-image>=0.16.2->atomai)
#   Using cached imageio-2.37.2-py3-none-any.whl.metadata (9.7 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image>=0.16.2->atomai)
#   Using cached tifffile-2025.5.10-py3-none-any.whl.metadata (31 kB)
# Collecting lazy-loader>=0.4 (from scikit-image>=0.16.2->atomai)
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from scikit-learn>=0.22.1->atomai) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from scikit-learn>=0.22.1->atomai) (3.6.0)
# Collecting greenlet>=1 (from sqlalchemy>=1.3.0->mendeleev<=0.6.1->atomai)
#   Using cached greenlet-3.3.0-cp310-cp310-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: filelock in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from torch>=1.0.0->atomai) (3.20.1)
# Collecting sympy>=1.13.3 (from torch>=1.0.0->atomai)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: jinja2 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from torch>=1.0.0->atomai) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from torch>=1.0.0->atomai) (2025.12.0)
# Collecting wadler-lindig>=0.1.3 (from jaxtyping->gpytorch>=1.9.1->atomai)
#   Using cached wadler_lindig-0.1.7-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from jinja2->torch>=1.0.0->atomai) (3.0.3)
# Using cached atomai-0.8.1-py3-none-any.whl (179 kB)
# Using cached gpytorch-1.14.3-py3-none-any.whl (280 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ---------------------------------------- 536.2/536.2 kB 2.5 MB/s  0:00:00
# Using cached linear_operator-0.6-py3-none-any.whl (176 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------ --------------------- 0.8/1.7 MB 3.7 MB/s eta 0:00:01
#    ------------------------------------ --- 1.6/1.7 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 3.7 MB/s  0:00:00
# Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl (39.0 MB)
# Using cached pandas-2.3.3-cp310-cp310-win_amd64.whl (11.3 MB)
# Using cached progressbar2-4.5.0-py3-none-any.whl (57 kB)
# Using cached python_utils-3.9.1-py2.py3-none-any.whl (32 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached scikit_image-0.25.2-cp310-cp310-win_amd64.whl (12.8 MB)
# Using cached imageio-2.37.2-py3-none-any.whl (317 kB)
# Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Using cached sqlalchemy-2.0.45-cp310-cp310-win_amd64.whl (2.1 MB)
# Using cached greenlet-3.3.0-cp310-cp310-win_amd64.whl (300 kB)
# Using cached tifffile-2025.5.10-py3-none-any.whl (226 kB)
# Downloading torch-2.9.1-cp310-cp310-win_amd64.whl (111.0 MB)
#    ---------------------------------------- 0.0/111.0 MB ? eta -:--:--
#    ---------------------------------------- 0.5/111.0 MB 3.4 MB/s eta 0:00:33
#    ---------------------------------------- 1.3/111.0 MB 4.0 MB/s eta 0:00:28
#     --------------------------------------- 2.1/111.0 MB 3.8 MB/s eta 0:00:29
#    - -------------------------------------- 3.1/111.0 MB 3.9 MB/s eta 0:00:28
#    - -------------------------------------- 3.9/111.0 MB 4.0 MB/s eta 0:00:27
#    - -------------------------------------- 5.0/111.0 MB 4.1 MB/s eta 0:00:26
#    -- ------------------------------------- 5.8/111.0 MB 4.1 MB/s eta 0:00:26
#    -- ------------------------------------- 6.8/111.0 MB 4.2 MB/s eta 0:00:25
#    -- ------------------------------------- 7.9/111.0 MB 4.3 MB/s eta 0:00:24
#    --- ------------------------------------ 8.7/111.0 MB 4.3 MB/s eta 0:00:25
#    --- ------------------------------------ 9.7/111.0 MB 4.3 MB/s eta 0:00:24
#    --- ------------------------------------ 10.7/111.0 MB 4.4 MB/s eta 0:00:23
#    ---- ----------------------------------- 11.8/111.0 MB 4.5 MB/s eta 0:00:23
#    ---- ----------------------------------- 12.8/111.0 MB 4.5 MB/s eta 0:00:22
#    ----- ---------------------------------- 13.9/111.0 MB 4.5 MB/s eta 0:00:22
#    ----- ---------------------------------- 14.9/111.0 MB 4.6 MB/s eta 0:00:21
#    ----- ---------------------------------- 16.5/111.0 MB 4.7 MB/s eta 0:00:20
#    ------ --------------------------------- 17.8/111.0 MB 4.8 MB/s eta 0:00:20
#    ------ --------------------------------- 19.4/111.0 MB 4.9 MB/s eta 0:00:19
#    ------- -------------------------------- 20.7/111.0 MB 5.0 MB/s eta 0:00:19
#    ------- -------------------------------- 21.8/111.0 MB 5.0 MB/s eta 0:00:18
#    -------- ------------------------------- 23.3/111.0 MB 5.1 MB/s eta 0:00:18
#    -------- ------------------------------- 24.6/111.0 MB 5.2 MB/s eta 0:00:17
#    --------- ------------------------------ 26.0/111.0 MB 5.2 MB/s eta 0:00:17
#    ---------- ----------------------------- 27.8/111.0 MB 5.4 MB/s eta 0:00:16
#    ---------- ----------------------------- 28.8/111.0 MB 5.4 MB/s eta 0:00:16
#    ---------- ----------------------------- 29.9/111.0 MB 5.3 MB/s eta 0:00:16
#    ----------- ---------------------------- 31.2/111.0 MB 5.4 MB/s eta 0:00:15
#    ----------- ---------------------------- 32.2/111.0 MB 5.4 MB/s eta 0:00:15
#    ------------ --------------------------- 33.3/111.0 MB 5.4 MB/s eta 0:00:15
#    ------------ --------------------------- 33.8/111.0 MB 5.3 MB/s eta 0:00:15
#    ------------ --------------------------- 34.9/111.0 MB 5.3 MB/s eta 0:00:15
#    ------------- -------------------------- 36.2/111.0 MB 5.3 MB/s eta 0:00:15
#    ------------- -------------------------- 36.4/111.0 MB 5.3 MB/s eta 0:00:15
#    ------------- -------------------------- 37.5/111.0 MB 5.2 MB/s eta 0:00:15
#    ------------- -------------------------- 38.8/111.0 MB 5.2 MB/s eta 0:00:14
#    -------------- ------------------------- 39.8/111.0 MB 5.2 MB/s eta 0:00:14
#    -------------- ------------------------- 41.2/111.0 MB 5.2 MB/s eta 0:00:14
#    --------------- ------------------------ 42.2/111.0 MB 5.2 MB/s eta 0:00:14
#    --------------- ------------------------ 43.5/111.0 MB 5.2 MB/s eta 0:00:13
#    ---------------- -----------------------
adler_lindig-0.1.7-py3-none-any.whl (20 kB)
# Using cached pyfiglet-1.0.4-py3-none-any.whl (1.8 MB)
# Installing collected packages: pytz, mpmath, wadler-lindig, tzdata, tifffile, sympy, python-utils, pyfiglet, opencv-python, networkx, lazy-loader, imageio, greenlet, torch, sqlalchemy, scikit-image, progressbar2, pandas, jaxtyping, torchvision, mendeleev, linear_operator, gpytorch, atomai
#
#    ----------------------------------------  0/24 [pytz]
#    - --------------------------------------  1/24 [mpmath]
#    - --------------------------------------  1/24 [mpmath]
#    - --------------------------------------  1/24 [mpmath]
#    ----- ----------------------------------  3/24 [tzdata]
#    ----- ----------------------------------  3/24 [tzdata]
#    ------ ---------------------------------  4/24 [tifffile]
#    ------ ---------------------------------  4/24 [tifffile]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    -------- -------------------------------  5/24 [sympy]
#    ---------- -----------------------------  6/24 [python-utils]
#    ----------- ----------------------------  7/24 [pyfiglet]
#    ----------- ----------------------------  7/24 [pyfiglet]
#    ------------- --------------------------  8/24 [opencv-python]
#    ------------- --------------------------  8/24 [opencv-python]
#    ------------- --------------------------  8/24 [opencv-python]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    ------------------ --------------------- 11/24 [imageio]
#    ------------------ --------------------- 11/24 [imageio]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    --------------------- ------------------ 13/24 [torch]
#    ----------------------- ---------------- 14/24 [sqlalchemy]
#    ----------------------- ---------------- 14/24 [sqlalchemy]
#    ----------------------- ---------------- 14/24 [sqlalchemy]
#    ----------------------- ---------------- 14/24 [sqlalchemy]
#    ----------------------- ---------------- 14/24 [sqlalchemy]
#    ----------------------- ---------------- 14/24 [sqlalchemy]
#    ----------------------- ---------------- 14/24 [sqlalchemy]
#    ----------------------- ---------------- 14/24 [sqlalchemy]
#    ----------------------- ---------------- 14/24 [sqlalchemy]
#    ------------------------- -------------- 15/24 [scikit-image]
#    ------------------------- -------------- 15/24 [scikit-image]
#    ------------------------- -------------- 15/24 [scikit-image]
#    ------------------------- -------------- 15/24 [scikit-image]
#    ------------------------- -------------- 15/24 [scikit-image]
#    ------------------------- -------------- 15/24 [scikit-image]
#    ------------------------- -------------- 15/24 [scikit-image]
#    ------------------------- -------------- 15/24 [scikit-image]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ---------------------------- ----------- 17/24 [pandas]
#    ------------------------------ --------- 18/24 [jaxtyping]
#    ------------------------------- -------- 19/24 [torchvision]
#    ------------------------------- -------- 19/24 [torchvision]
#    ------------------------------- -------- 19/24 [torchvision]
#    ------------------------------- -------- 19/24 [torchvision]
#    ----------------------------------- ---- 21/24 [linear_operator]
#    ------------------------------------ --- 22/24 [gpytorch]
#    ------------------------------------ --- 22/24 [gpytorch]
#    ------------------------------------ --- 22/24 [gpytorch]
#    -------------------------------------- - 23/24 [atomai]
#    -------------------------------------- - 23/24 [atomai]
#    ---------------------------------------- 24/24 [atomai]
#
# Successfully installed atomai-0.8.1 gpytorch-1.14.3 greenlet-3.3.0 imageio-2.37.2 jaxtyping-0.3.4 lazy-loader-0.4 linear_operator-0.6 mendeleev-0.6.1 mpmath-1.3.0 networkx-3.4.2 opencv-python-4.12.0.88 pandas-2.3.3 progressbar2-4.5.0 pyfiglet-1.0.4 python-utils-3.9.1 pytz-2025.2 scikit-image-0.25.2 sqlalchemy-2.0.45 sympy-1.14.0 tifffile-2025.5.10 torch-2.9.1 torchvision-0.24.1 tzdata-2025.3 wadler-lindig-0.1.7
# Collecting pytemlib
#   Using cached pytemlib-0.2025.12.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: scipy in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from pytemlib) (1.15.3)
# Requirement already satisfied: numpy in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from pytemlib) (2.2.6)
# Requirement already satisfied: pillow in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from pytemlib) (12.0.0)
# Requirement already satisfied: ase in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from pytemlib) (3.26.0)
# Requirement already satisfied: tqdm in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from pytemlib) (4.67.1)
# Collecting plotly (from pytemlib)
#   Using cached plotly-6.5.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: pandas in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from pytemlib) (2.3.3)
# Requirement already satisfied: requests in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from pytemlib) (2.32.5)
# Collecting lxml (from pytemlib)
#   Using cached lxml-6.0.2-cp310-cp310-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: ipympl in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from pytemlib) (0.9.8)
# Collecting spglib (from pytemlib)
#   Using cached spglib-2.6.0-cp310-cp310-win_amd64.whl.metadata (4.2 kB)
# Collecting simpleitk (from pytemlib)
#   Using cached simpleitk-2.5.3-cp310-cp310-win_amd64.whl.metadata (7.3 kB)
# Requirement already satisfied: scikit-image in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from pytemlib) (0.25.2)
# Requirement already satisfied: scikit-learn in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from pytemlib) (1.7.2)
# Requirement already satisfied: pyNSID>=0.0.7 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from pytemlib) (0.0.7.2)
# Requirement already satisfied: sidpy>=0.12.7 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from pytemlib) (0.12.8)
# Requirement already satisfied: SciFiReaders>=0.12.4 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from pytemlib) (0.12.4)
# Collecting xraylib (from pytemlib)
#   Using cached xraylib-4.2.0-cp310-cp310-win_amd64.whl.metadata (1.9 kB)
# Requirement already satisfied: toolz in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from pyNSID>=0.0.7->pytemlib) (1.1.0)
# Requirement already satisfied: cytoolz in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from pyNSID>=0.0.7->pytemlib) (1.1.0)
# Requirement already satisfied: dask>=0.10 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from pyNSID>=0.0.7->pytemlib) (2025.12.0)
# Requirement already satisfied: h5py>=2.6.0 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from pyNSID>=0.0.7->pytemlib) (3.15.1)
# Requirement already satisfied: six in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from pyNSID>=0.0.7->pytemlib) (1.17.0)
# Requirement already satisfied: click>=8.1 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from dask>=0.10->pyNSID>=0.0.7->pytemlib) (8.3.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from dask>=0.10->pyNSID>=0.0.7->pytemlib) (3.1.2)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from dask>=0.10->pyNSID>=0.0.7->pytemlib) (2025.12.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from dask>=0.10->pyNSID>=0.0.7->pytemlib) (25.0)
# Requirement already satisfied: partd>=1.4.0 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from dask>=0.10->pyNSID>=0.0.7->pytemlib) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from dask>=0.10->pyNSID>=0.0.7->pytemlib) (6.0.3)
# Requirement already satisfied: importlib_metadata>=4.13.0 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from dask>=0.10->pyNSID>=0.0.7->pytemlib) (8.7.0)
# Requirement already satisfied: colorama in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from click>=8.1->dask>=0.10->pyNSID>=0.0.7->pytemlib) (0.4.6)
# Requirement already satisfied: zipp>=3.20 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from importlib_metadata>=4.13.0->dask>=0.10->pyNSID>=0.0.7->pytemlib) (3.23.0)
# Requirement already satisfied: locket in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from partd>=1.4.0->dask>=0.10->pyNSID>=0.0.7->pytemlib) (1.0.0)
# Requirement already satisfied: setuptools in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from SciFiReaders>=0.12.4->pytemlib) (80.9.0)
# Requirement already satisfied: numba in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from SciFiReaders>=0.12.4->pytemlib) (0.63.1)
# Requirement already satisfied: ipython>=7.1.0 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from SciFiReaders>=0.12.4->pytemlib) (8.37.0)
# Requirement already satisfied: pyUSID in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from SciFiReaders>=0.12.4->pytemlib) (0.0.12)
# Requirement already satisfied: gdown in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from SciFiReaders>=0.12.4->pytemlib) (5.2.0)
# Requirement already satisfied: mrcfile in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from SciFiReaders>=0.12.4->pytemlib) (1.5.4)
# Requirement already satisfied: pycroscopy-gwyfile in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from SciFiReaders>=0.12.4->pytemlib) (1.0.2)
# Requirement already satisfied: decorator in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from ipython>=7.1.0->SciFiReaders>=0.12.4->pytemlib) (5.2.1)
# Requirement already satisfied: exceptiongroup in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from ipython>=7.1.0->SciFiReaders>=0.12.4->pytemlib) (1.3.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from ipython>=7.1.0->SciFiReaders>=0.12.4->pytemlib) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from ipython>=7.1.0->SciFiReaders>=0.12.4->pytemlib) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from ipython>=7.1.0->SciFiReaders>=0.12.4->pytemlib) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from ipython>=7.1.0->SciFiReaders>=0.12.4->pytemlib) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from ipython>=7.1.0->SciFiReaders>=0.12.4->pytemlib) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from ipython>=7.1.0->SciFiReaders>=0.12.4->pytemlib) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from ipython>=7.1.0->SciFiReaders>=0.12.4->pytemlib) (4.15.0)
# Requirement already satisfied: wcwidth in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.1.0->SciFiReaders>=0.12.4->pytemlib) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from jedi>=0.16->ipython>=7.1.0->SciFiReaders>=0.12.4->pytemlib) (0.8.5)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from sidpy>=0.12.7->pytemlib) (3.10.8)
# Requirement already satisfied: distributed>=2.0.0 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from sidpy>=0.12.7->pytemlib) (2025.12.0)
# Requirement already satisfied: joblib>=0.11.0 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from sidpy>=0.12.7->pytemlib) (1.5.3)
# Requirement already satisfied: ipywidgets in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from sidpy>=0.12.7->pytemlib) (8.1.8)
# Requirement already satisfied: ipykernel in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from sidpy>=0.12.7->pytemlib) (7.1.0)
# Requirement already satisfied: dill in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from sidpy>=0.12.7->pytemlib) (0.4.0)
# Requirement already satisfied: jinja2>=2.10.3 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from distributed>=2.0.0->sidpy>=0.12.7->pytemlib) (3.1.6)
# Requirement already satisfied: msgpack>=1.0.2 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from distributed>=2.0.0->sidpy>=0.12.7->pytemlib) (1.1.2)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from distributed>=2.0.0->sidpy>=0.12.7->pytemlib) (7.1.3)
# Requirement already satisfied: sortedcontainers>=2.0.5 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from distributed>=2.0.0->sidpy>=0.12.7->pytemlib) (2.4.0)
# Requirement already satisfied: tblib!=3.2.0,!=3.2.1,>=1.6.0 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from distributed>=2.0.0->sidpy>=0.12.7->pytemlib) (3.2.2)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from distributed>=2.0.0->sidpy>=0.12.7->pytemlib) (6.5.4)
# Requirement already satisfied: urllib3>=1.26.5 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from distributed>=2.0.0->sidpy>=0.12.7->pytemlib) (2.6.2)
# Requirement already satisfied: zict>=3.0.0 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from distributed>=2.0.0->sidpy>=0.12.7->pytemlib) (3.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from jinja2>=2.10.3->distributed>=2.0.0->sidpy>=0.12.7->pytemlib) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from matplotlib>=2.0.0->sidpy>=0.12.7->pytemlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from matplotlib>=2.0.0->sidpy>=0.12.7->pytemlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from matplotlib>=2.0.0->sidpy>=0.12.7->pytemlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from matplotlib>=2.0.0->sidpy>=0.12.7->pytemlib) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from matplotlib>=2.0.0->sidpy>=0.12.7->pytemlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from matplotlib>=2.0.0->sidpy>=0.12.7->pytemlib) (2.9.0.post0)
# Requirement already satisfied: beautifulsoup4 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from gdown->SciFiReaders>=0.12.4->pytemlib) (4.14.3)
# Requirement already satisfied: filelock in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from gdown->SciFiReaders>=0.12.4->pytemlib) (3.20.1)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from beautifulsoup4->gdown->SciFiReaders>=0.12.4->pytemlib) (2.8)
# Requirement already satisfied: comm>=0.1.1 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from ipykernel->sidpy>=0.12.7->pytemlib) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from ipykernel->sidpy>=0.12.7->pytemlib) (1.8.19)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from ipykernel->sidpy>=0.12.7->pytemlib) (8.7.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from ipykernel->sidpy>=0.12.7->pytemlib) (5.9.1)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from ipykernel->sidpy>=0.12.7->pytemlib) (1.6.0)
# Requirement already satisfied: pyzmq>=25 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from ipykernel->sidpy>=0.12.7->pytemlib) (27.1.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->sidpy>=0.12.7->pytemlib) (4.5.1)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from ipywidgets->sidpy>=0.12.7->pytemlib) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from ipywidgets->sidpy>=0.12.7->pytemlib) (3.0.16)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from numba->SciFiReaders>=0.12.4->pytemlib) (0.46.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from pandas->pytemlib) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from pandas->pytemlib) (2025.3)
# Collecting narwhals>=1.15.1 (from plotly->pytemlib)
#   Using cached narwhals-2.14.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from requests->pytemlib) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from requests->pytemlib) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from requests->pytemlib) (2025.11.12)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from requests[socks]->gdown->SciFiReaders>=0.12.4->pytemlib) (1.7.1)
# Requirement already satisfied: networkx>=3.0 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from scikit-image->pytemlib) (3.4.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from scikit-image->pytemlib) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from scikit-image->pytemlib) (2025.5.10)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from scikit-image->pytemlib) (0.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from scikit-learn->pytemlib) (3.6.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from stack_data->ipython>=7.1.0->SciFiReaders>=0.12.4->pytemlib) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from stack_data->ipython>=7.1.0->SciFiReaders>=0.12.4->pytemlib) (3.0.1)
# Requirement already satisfied: pure_eval in c:\users\jcruanes\.conda\envs\hackathonnew\lib\site-packages (from stack_data->ipython>=7.1.0->SciFiReaders>=0.12.4->pytemlib) (0.2.3)
# Using cached pytemlib-0.2025.12.0-py3-none-any.whl (1.5 MB)
# Using cached lxml-6.0.2-cp310-cp310-win_amd64.whl (4.0 MB)
# Using cached plotly-6.5.0-py3-none-any.whl (9.9 MB)
# Using cached narwhals-2.14.0-py3-none-any.whl (430 kB)
# Using cached simpleitk-2.5.3-cp310-cp310-win_amd64.whl (18.8 MB)
# Using cached spglib-2.6.0-cp310-cp310-win_amd64.whl (561 kB)
# Using cached xraylib-4.2.0-cp310-cp310-win_amd64.whl (14.9 MB)
# Installing collected packages: simpleitk, xraylib, spglib, narwhals, lxml, plotly, pytemlib
#
#    ---------------------------------------- 0/7 [simpleitk]
#    ---------------------------------------- 0/7 [simpleitk]
#    ----------- ---------------------------- 2/7 [spglib]
#    ----------------- ---------------------- 3/7 [narwhals]
#    ----------------- ---------------------- 3/7 [narwhals]
#    ----------------- ---------------------- 3/7 [narwhals]
#    ---------------------- ----------------- 4/7 [lxml]
#    ---------------------- ----------------- 4/7 [lxml]
#    ---------------------------- ----------- 5/7 [plotly]
#    ---------------------------- ----------- 5/7 [plotly]
#    ---------------------------- ----------- 5/7 [plotly]
#    ---------------------------- ----------- 5/7 [plotly]
#    ---------------------------- ----------- 5/7 [plotly]
#    ---------------------------- ----------- 5/7 [plotly]
#    ---------------------------- ----------- 5/7 [plotly]
#    ---------------------------- ----------- 5/7 [plotly]
#    ---------------------------- ----------- 5/7 [plotly]
#    ---------------------------- ----------- 5/7 [plotly]
#    ---------------------------- ----------- 5/7 [plotly]
#    ---------------------------- ----------- 5/7 [plotly]
#    ---------------------------- ----------- 5/7 [plotly]
#    ---------------------------- ----------- 5/7 [plotly]
#    ---------------------------- ----------- 5/7 [plotly]
#    ---------------------------- ----------- 5/7 [plotly]
#    ---------------------------- ----------- 5/7 [plotly]
#    ---------------------------- ----------- 5/7 [plotly]
#    ---------------------------- ----------- 5/7 [plotly]
#    ---------------------------- ----------- 5/7 [plotly]
#    ---------------------------- ----------- 5/7 [plotly]
#    ---------------------------- ----------- 5/7 [plotly]
#    ---------------------------- ----------- 5/7 [plotly]
#    ---------------------------- ----------- 5/7 [plotly]
#    ---------------------------- ----------- 5/7 [plotly]
#    ---------------------------- ----------- 5/7 [plotly]
#    ---------------------------- ----------- 5/7 [plotly]
#    ---------------------------- ----------- 5/7 [plotly]
#    ---------------------------- ----------- 5/7 [plotly]
#    ---------------------------------- ----- 6/7 [pytemlib]
#    ---------------------------------- ----- 6/7 [pytemlib]
#    ---------------------------------- ----- 6/7 [pytemlib]
#    ---------------------------------------- 7/7 [pytemlib]
#
# Successfully installed lxml-6.0.2 narwhals-2.14.0 plotly-6.5.0 pytemlib-0.2025.12.0 simpleitk-2.5.3 spglib-2.6.0 xraylib-4.2.0

# %%
# !run_server_stem

# %% [markdown]
# ## Client side starts

# %%
import matplotlib.pylab as plt
import numpy as np
import Pyro5.api
import cv2
from atomai import utils

# %% [markdown]
# ### 1. connect to server

# %%
# Connect to the microscope server
uri = "PYRO:microscope.server@localhost:9091"
mic_server = Pyro5.api.Proxy(uri)
out_dir = "."

# %% [markdown]
# ### 2. Download and Register dataset

# %% [markdown]
# #### 2a. download dataset

# %%
# !pip install wget
# Out:
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: wget
#   Building wheel for wget
plt.imshow(im_array)
# plt.axis("off")
plt.title("Overview Image")
plt.show()

# %% [markdown]
# ### 3. Get spectra at all pixels

# %% [markdown]
# Let's extract the spectrum from each pixel in the image and store it in a 3D array.

# %%
height, width = im_array.shape

spectra = []
locations = []
for x in range(height):
    for y in range(width):
        array_list, shape, dtype = mic_server.get_point_data("Channel_001", x, y)
        spectrum = np.array(array_list, dtype=dtype).reshape(shape)
        spectra.append(spectrum)
        locations.append((x, y))

spectra = np.array(spectra).reshape(height, width, -1)  # Convert list of spectra to a NumPy array
spectra.shape
# Out:
# (62, 75, 1496)

# %%
def preprocess_and_extract_patches(im_array, spectra, window_size=20, step=1):
    """
    Normalize input image and spectra, generate coordinate grid, and extract image patches and corresponding spectra.

    Parameters:
    im_array (np.array): 2D image array to extract patches from.
    spectra (np.array): Array of spectra corresponding to the image.
    window_size (int): Size of the window for patches.
    step (int): Step size for sliding window.

    Returns:
    features (np.array): Extracted image patches.
    targets (np.array): Averaged spectra for each patch.
    indices (np.array): Coordinates of each patch.
    """

    # Normalization functions for image and spectra maps
    norm_ = lambda x: (x - x.min()) / np.ptp(x)
    img = norm_(im_array)
    specim = norm_(spectra)

    # Generate coordinates grid
    coordinates = utils.get_coord_grid(img, step=step, return_dict=False)

    # Extract image patches and corresponding spectra
    features, targets, indices = utils.extract_patches_and_spectra(
        specim, img, coordinates=coordinates, window_size=window_size, avg_pool=1
    )

    return features, targets, indices

# %% [markdown]
# We use the extract_patches_and_spectra function from atomAI to extract patches based on a specified window size, along with their corresponding spectra. For each patch, all spectra from that patch are averaged to produce a single mean spectrum, resulting in one representative spectrum for each image patch

# %%
#Features are the image patches and targets are the spectra for teh corresponding patch
features, targets, indices = preprocess_and_extract_patches(im_array, spectra, window_size=20, step=1)
features.shape, targets.shape
# Out:
# c:\Users\jcruanes\.conda\envs\HackathonNew\lib\site-packages\atomai\utils\img.py:450: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\torch\csrc\utils\tensor_new.cpp:256.)
#   spectra = torch.tensor(spectra).unsqueeze(1)
# ((2408, 20, 20), (2408, 1496))

# %%
import random

# Select 20 random patches
num_patches_to_show = 100
random_indices = random.sample(range(len(features)), num_patches_to_show)
selected_patches = features[random_indices]

output_dir = "parches_guardados"
os.makedirs(output_dir, exist_ok=True)


# Create a 4x5 grid for displaying the patches
fig, axes = plt.subplots(10, 10, figsize=(10, 10))

# Flatten the axes array for easier iteration
axes = axes.ravel()


# Display the selected patches
for i, patch in enumerate(selected_patches):
    axes[i].imshow(patch)
    axes[i].axis('off')
    filename = os.path.join(output_dir, f"Imagen_{i+1}.png")
    plt.imsave(filename, patch)

# Turn off any remaining empty subplots
for j in range(i + 1, len(axes)):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %%
# Select corresponding targets for the random indices
selected_targets = targets[random_indices]

# Create a 4x5 grid for displaying the targets
fig, axes = plt.subplots(4, 5, figsize=(15, 10))
axes = axes.ravel()  # Flatten the axes array

# Plot the selected targets
for i, target in enumerate(selected_targets):
    axes[i].plot(target)  # Plot the target as a line plot
    axes[i].axis('on')  # Keep axis labels

# Turn off any remaining empty subplots
for j in range(i + 1, len(axes)):
    axes[j].axis('off')

plt.tight_layout()
plt.show()
